# %%
import datetime
import math
a = int(input("Введите число: "))
print(f"Корень из {a} равен {math.sqrt(a)}")
print(datetime.datetime.now())
# Out:
# Введите число: 5
# Корень из 5 равен 2.23606797749979
# 2024-10-06 11:32:19.644707
